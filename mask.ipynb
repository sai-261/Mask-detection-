# %%
# !git clone https://github.com/ultralytics/yolov5 
# !pip install -U -r yolov5/requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10469, done.
# remote: Total 10469 (delta 0), reused 0 (delta 0), pack-reused 10469
# Receiving objects: 100% (10469/10469), 10.67 MiB | 7.55 MiB/s, done.
# Resolving deltas: 100% (7229/7229), done.
# ...
#      |████████████████████████████████| 11.2 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 51.2 MB/s
# ...
#      |████████████████████████████████| 60.4 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 41.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 37.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...

# %%
cd yolov5/
# Out:
# /content/yolov5

# %%
! pip install -r requirements.txt

# %%
! python train.py --img 640 --batch 13 --epochs 50 --data custom.yaml --weights yolov5x.pt --nosave --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=13, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-181-gf80c463 torch 1.10.1+cu102 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp7/weights/last.pt --img 640 --conf 0.25 --source /content/yolov5/test
# Out:
# detect: weights=['runs/train/exp7/weights/last.pt'], source=/content/yolov5/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-181-gf80c463 torch 1.10.1+cu102 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86180143 parameters, 0 gradients, 204.0 GFLOPs
# image 1/8 /content/yolov5/test/test1.jpg: 640x448 1 mask, Done. (0.175s)
# image 2/8 /content/yolov5/test/test2.jpg: 640x512 1 mask, Done. (0.177s)
# image 3/8 /content/yolov5/test/test3.jpg: 512x640 1 mask, Done. (0.163s)
# image 4/8 /content/yolov5/test/test4.jpg: 384x640 3 masks, Done. (0.125s)
# ...
